# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\Academics\Self Projects\Airline TS Project\airline-passengers.csv")

# %%
df
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
df = df.rename(columns={'Month': 'ds', 'Passengers': 'y'})

# %%
df.dtypes
# Out:
# ds    object
# y      int64
# dtype: object

# %%
df['ds'] = pd.to_datetime(df['ds'], format='%Y-%m')

# %%
df
# Out:
#             ds    y
# 0   1949-01-01  112
# 1   1949-02-01  118
# 2   1949-03-01  132
# 3   1949-04-01  129
# 4   1949-05-01  121
# ..         ...  ...
# 139 1960-08-01  606
# 140 1960-09-01  508
# 141 1960-10-01  461
# 142 1960-11-01  390
# 143 1960-12-01  432
#
# [144 rows x 2 columns]

# %%
df.dtypes
# Out:
# ds    datetime64[ns]
# y              int64
# dtype: object

# %%
from prophet import Prophet

# %%
model = Prophet()

# %%
model.fit(df)
# Out:
# 20:27:34 - cmdstanpy - INFO - Chain [1] start processing
# 20:27:34 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=36, freq="MS")

# %%
forecast = model.predict(future)

# %%
model.plot(forecast)
plt.show()

# %%
forecast_values = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].rename(columns={
    'yhat': 'y_forecasted',
    'yhat_lower': 'y_forecasted_lower',
    'yhat_upper': 'y_forecasted_upper',
    'ds': 'Month'  
})

# %%
df = df.rename(columns={'ds': 'Month', 'y': 'Passengers'})

# %%
df
# Out:
#          Month  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 139 1960-08-01         606
# 140 1960-09-01         508
# 141 1960-10-01         461
# 142 1960-11-01         390
# 143 1960-12-01         432
#
# [144 rows x 2 columns]

# %%
df_full = pd.merge(df, forecast_values, on='Month', how='right')

# %%
df_full
# Out:
#          Month  Passengers  y_forecasted  y_forecasted_lower  \
# 0   1949-01-01       112.0     84.814159           55.507827
# 1   1949-02-01       118.0     78.227931           50.341138
# 2   1949-03-01       132.0    110.342237           80.869776
# 3   1949-04-01       129.0    107.810718           78.182069
# 4   1949-05-01       121.0    111.266255           80.319868
# ..         ...         ...           ...                 ...
# 175 1963-08-01         NaN    649.848630          621.170626
# 176 1963-09-01         NaN    602.344925          572.740417
# 177 1963-10-01         NaN    566.285229          538.449688
# 178 1963-11-01         NaN    534.334833          504.050216
# 179 1963-12-01         NaN    563.989108          533.287648
#
#      y_forecasted_upper
# 0            115.591663
# 1            108.032880
# 2            138.937734
# 3            138.625198
# 4            139.674802
# ..                  ...
# 175          678.130464
# 176          632.901343
# 177          594.430766
# 178          563.980647
# 179          592.364241
#
# [180 rows x 5 columns]

# %%
df_full = df_full.drop(columns=['y_forecasted_lower', 'y_forecasted_upper'])

# %%
df_full = df_full.rename(columns={'y_forecasted': 'forecasted'})

# %%
df_full.tail(38)
# Out:
#          Month  Passengers  forecasted
# 142 1960-11-01       390.0  421.955303
# 143 1960-12-01       432.0  451.174702
# 144 1961-01-01         NaN  465.855759
# 145 1961-02-01         NaN  460.213899
# 146 1961-03-01         NaN  493.181183
# 147 1961-04-01         NaN  491.594032
# 148 1961-05-01         NaN  495.963474
# 149 1961-06-01         NaN  536.880539
# 150 1961-07-01         NaN  576.558728
# 151 1961-08-01         NaN  576.981538
# 152 1961-09-01         NaN  528.467170
# 153 1961-10-01         NaN  493.212958
# 154 1961-11-01         NaN  459.387291
# 155 1961-12-01         NaN  488.809057
# 156 1962-01-01         NaN  501.729968
# 157 1962-02-01         NaN  495.577274
# 158 1962-03-01         NaN  531.141253
# 159 1962-04-01         NaN  527.405532
# 160 1962-05-01         NaN  533.337754
# 161 1962-06-01         NaN  572.941402
# 162 1962-07-01         NaN  613.493986
# 163 1962-08-01         NaN  613.421801
# 164 1962-09-01         NaN  565.403222
# 165 1962-10-01         NaN  529.739979
# 166 1962-11-01         NaN  496.847483
# 167 1962-12-01         NaN  526.414270
# 168 1963-01-01         NaN  537.568824
# 169 1963-02-01         NaN  530.965813
# 170 1963-03-01         NaN  569.100564
# 171 1963-04-01         NaN  563.214974
# 172 1963-05-01         NaN  570.720215
# 173 1963-06-01         NaN  608.995610
# 174 1963-07-01         NaN  650.417341
# 175 1963-08-01         NaN  649.848630
# 176 1963-09-01         NaN  602.344925
# 177 1963-10-01         NaN  566.285229
# 178 1963-11-01         NaN  534.334833
# 179 1963-12-01         NaN  563.989108

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import numpy as np

# %%
historical_data = df_full.iloc[:144]
mae = mean_absolute_error(historical_data['Passengers'], historical_data['forecasted'])
mse = mean_squared_error(historical_data['Passengers'], historical_data['forecasted'])
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(historical_data['Passengers'], historical_data['forecasted'])

# %%
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Percentage Error (MAPE): {mape * 100:.2f}%")
# Out:
# Mean Absolute Error (MAE): 17.38237120047183
# Mean Squared Error (MSE): 505.2555358709972
# Root Mean Squared Error (RMSE): 22.477889933688108
# Mean Absolute Percentage Error (MAPE): 7.27%

# %%
from sklearn.metrics import r2_score

# %%
r2_score(historical_data['Passengers'], historical_data['forecasted'])
# Out:
# 0.9646476015484314
